# %%
# Import dependencies
import pandas as pd
import os

# %%
# Assign variables for files to load via indirect path.
movies_csv = os.path.join("ETL_classwork", "movies_metadata.csv")
ratings_csv = os.path.join("ETL_classwork", "ratings.csv")

# %%
# Read data and store it in Pandas
# No _df variable until data is satisfactory, then store in DataFrame
kaggle_metadata = pd.read_csv(movies_csv, low_memory=False)
ratings = pd.read_csv(ratings_csv)

# %%
kaggle_metadata.sample(5)
# Out:
#        adult                              belongs_to_collection  budget  \
# 5714   False                                                NaN       0
# 20991  False  {'id': 476071, 'name': "The Devil's Carnival C...  500000
# 23585  False                                                NaN       0
# 29883  False                                                NaN       0
# 32240  False                                                NaN       0
#
#                                                   genres  \
# 5714   [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 20991                     [{'id': 27, 'name': 'Horror'}]
# 23585  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 29883  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 32240  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
#
#                                 homepage      id    imdb_id original_language  \
# 5714                                 NaN   20472  tt0083033                en
# 20991  http://www.thedevilscarnival.com/  100493  tt2204379                en
# 23585                                NaN   28006  tt0038289                en
# 29883                                NaN   21625  tt1261047                en
# 32240                                NaN   57857  tt0112667                en
#
#               original_title  \
# 5714       Saturday the 14th
# 20991   The Devil's Carnival
# 23585  I See a Dark Stranger
# 29883                 Gulaal
# 32240      The Christmas Box
#
#                                                 overview  ... release_date  \
# 5714   Primarily a spoof of the Friday the 13th serie...  ...   1981-10-30
# 20991  Sinners are invited to a theme park where they...  ...   2012-04-05
# 23585  Determined, independent Bridie Quilty comes of...  ...   1946-07-04
# 29883  Gulaal is set in Rajpur a fictional city of Ra...  ...   2009-03-13
# 32240  A ski-shop owner reluctantly moves himself, hi...  ...   1995-12-17
#
#       revenue runtime                          spoken_languages    status  \
# 5714      0.0    75.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 20991     0.0    55.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 23585     0.0   112.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29883     0.0   140.0   [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]  Released
# 32240     0.0   100.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 5714   Just when you thought it was safe to look at t...
# 20991                           You can't help but fall.
# 23585  The woman hunt is on... For the girl with the ...
# 29883                                                NaN
# 32240                                                NaN
#
#                        title  video vote_average vote_count
# 5714       Saturday the 14th  False          5.1       15.0
# 20991   The Devil's Carnival  False          5.3       33.0
# 23585  I See a Dark Stranger  False          5.1        6.0
# 29883                 Gulaal  False          6.7       16.0
# 32240      The Christmas Box  False          4.6        5.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(5)
# Out:
#           userId  movieId  rating   timestamp
# 471834      4899      260     3.5  1458284940
# 5284412    54511     7361     4.5  1147371627
# 9345719    96563     7438     4.5  1273161534
# 22759447  236512      541     5.0  1001630706
# 16759270  174257   158872     5.0  1491608856
